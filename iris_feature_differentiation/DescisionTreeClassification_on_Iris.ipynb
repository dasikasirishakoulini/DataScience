# %% [markdown]
# # **PREDICTION USING DECISION TREE ALGORITHM**

# %% [markdown]
# **AIM:** Create a Decision Tree Classifier and visualize it graphically

# %% [markdown]
# ## **DECISION TREE**

# %% [markdown]
# A decision tree is a decision support tool that uses a tree-like model of decisions and their possible consequences, including chance event outcomes, resource costs, and utility. It is one way to display an algorithm that only contains conditional control statements
#
# *PROPERTIES*
#
# * SIMPLICITY: Decision Trees are simple, visually appealing and are easy to interpret.
#
# * Accuracy: Advance Decision Tree models show exeptional performance in predicting patterns in complex data.

# %% [markdown]
# *A Decision Tree consists of three types of nodes*
#
#    * Root Nodes
#
#    * Decision Nodes
#
#    * Leaf Nodes
#
# Each node in the tree acts as a test case for some attribute and each edge descending from that node corresponds to one of the possible answers to the test case.
# This process is recursive and is repeated for every subtree rooted at the new nodes.
#
#    * 1.Root Node- The very top node is called the Root Node or just a Node.It is also called as a Top Decision Node.It represents the entire population or sample, and this further gets divided into two or more homogeneous sets.
#
#    * 2.Decision Node- When a sub-node splits into further sub-nodes, then it is called a decision node.These are also called as Internal nodes. Internal Nodes have arrows pointing to them.
#
#    * 3.Leaf/ Terminal Node-Nodes with no children(no further split) is called leaf. Leaf Nodes have arrows pointing to them, but there  are no arrows pointing away from them.

# %% [markdown]
# ![DecisionTree.png](attachment:DecisionTree.png)

# %% [markdown]
# Decision trees can be applied to both Regression and Classification Problems
#
# The Basic Idea behind Decision Tree Algorithm
#
#    * 1.Select the best attribute using Attribute Selection Measures to split the records
#    * 2.Make the attribute a decision node and break the dataset into smaller subsets
#    * 3.Start tree building by repeating this process recursively for each child until there are no more remaining attributes

# %% [markdown]
# ## IRIS DATASET IS USED FOR DECISSION TREE CLASSIFICATION
#
# The dataset consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolour). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.

# %% [markdown]
# ![IrisFlower.png](attachment:IrisFlower.png)

# %% [markdown]
# ## **Classification**

# %%
# Importing the libraries
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
# Loading the Iris data
data  = load_iris()
data.data.shape
# Out:
# (150, 4)

# %%
print('Classes to Predict: ', iris.target_names)
# Out:
# Classes to Predict:  ['setosa' 'versicolor' 'virginica']

# %%
print('Features: ', data.feature_names)
# Out:
# Features:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# Extracting the data attributes
X = data.data

# Extracting target/class labels
y = data.target

# %%
# Shape of the dataset
display(X.shape, y.shape)
# Out:
# (150, 4)
# (150,)

# %%
# Import library for splitting the data into train and test
from sklearn.model_selection import train_test_split

# %%
# Using the train_test_split to create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 50, test_size = 0.25)

# %%
# Importing the DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
# Training the Decision Tree Classifier
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Prediction
y_pred = clf.predict(X_test)

# %%
# Importing Accuracy Score
from sklearn.metrics import accuracy_score

# %%
print('Accuracy Score on train data (using Default criterion as gini):', accuracy_score(y_true=y_train, y_pred=clf.predict(X_train)))
print('Accuracy Score on test data (using Default criterion as gini):', accuracy_score(y_true=y_test,y_pred=y_pred))
# Out:
# Accuracy Score on train data (using Default criterion as gini): 1.0
# Accuracy Score on test data (using Default criterion as gini): 0.9473684210526315

# %%
# Changing the Criterion to Entropy
clf_entropy = DecisionTreeClassifier(criterion = 'entropy')

# %%
# Training the DecisionTreeClassifier
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Predicting labels on the data set
y_pred_entropy = clf_entropy.predict(X_test)

# %%
print('Accuracy Score on train data (using Default criterion as Entropy):', accuracy_score(y_true=y_train, y_pred=clf_entropy.predict(X_train)))
print('Accuracy Score on test data (using Default criterion as Entropy):', accuracy_score(y_true=y_test, y_pred=y_pred_entropy))
# Out:
# Accuracy Score on train data (using Default criterion as Entropy): 1.0
# Accuracy Score on test data (using Default criterion as Entropy): 0.9473684210526315

# %%
# After tune the parameters of the decision tree to increase its accuracy
clf2 = DecisionTreeClassifier(criterion='entropy', min_samples_split=50)
clf2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=50)

# %%
print('Accuracy Score on train data (using Default criterion as Entropy & min_samples_split):', accuracy_score(y_true=y_train, y_pred=clf2.predict(X_train)))
print('Accuracy Score on the test data (using Default criterion as Entropy & min_samples_split):', accuracy_score(y_true=y_test, y_pred=clf2.predict(X_test)))
# Out:
# Accuracy Score on train data (using Default criterion as Entropy & min_samples_split): 0.9642857142857143
# Accuracy Score on the test data (using Default criterion as Entropy & min_samples_split): 0.9473684210526315

# %%
# Installing pydotplus
# !pip install pydotplus

# %%
# Installing six
# !pip install six

# %% [markdown]
# ## Decision Tree Visualization

# %%
# Installing the libraries for visualization
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(clf, out_file = dot_data, filled = True, rounded = True, special_characters = True, feature_names = data.feature_names, class_names = data.target_names)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# **Change the Decision Tree Default criterion gini to entropy**

# %%
clf3 = DecisionTreeClassifier(criterion = 'entropy')

# %%
clf3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dot_data = StringIO()
export_graphviz(clf3, out_file = dot_data, filled = True, rounded = True, special_characters = True, feature_names = data.feature_names, class_names = data.target_names)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
